# %%
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
CA_file = "Resources/CAvideos.csv"
CA_df = pd.read_csv(CA_file)
CA_df.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
MX_file = "Resources/MXvideos.csv"
MX_df = pd.read_csv(MX_file, encoding="ISO-8859-1")
MX_df.head()
# Out:
#       video_id trending_date  \
# 0  SbOwzAl9ZfQ      17.14.11
# 1  klOV6Xh-DnI      17.14.11
# 2  6L2ZF7Qzsbk      17.14.11
# 3  hcY52MFWMDM      17.14.11
# 4  _OXDcGPVAa4      17.14.11
#
#                                                title  \
# 0                     CapÃ­tulo 12 | MasterChef 2017
# 1  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 2           LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA
# 3   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# 4           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                channel_title  category_id              publish_time  \
# 0            MasterChef 2017           24  2017-11-13T06:06:22.000Z
# 1   Micky Contreras Martinez           22  2017-11-13T05:11:58.000Z
# 2  El Pulso De La RepÃºblica           25  2017-11-13T17:00:02.000Z
# 3                   Casanare           25  2017-11-13T03:47:10.000Z
# 4                      Musas           26  2017-11-13T19:17:48.000Z
#
# ...

# %%
US_file = "Resources/USvideos.csv"
US_df = pd.read_csv(US_file)
US_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %% [markdown]
# ### Transform Canada DataFrame

# %%
# Create a filtered DataFrame from specific columns
CA_cols = ["video_id", "trending_date", "title", "category_id", "publish_time",
           "views", "likes", "dislikes", "comment_count"]
CA_transformed = CA_df[CA_cols].copy()

# Add a column to specify country
CA_transformed.insert(5, "country", "Canada")

# Create a dict to convert category_id to category name
categories = {
    1:"Film & Animation", 2:"Autos & Vehicles", 10:"Music", 15:"Pets & Animals",
    17:"Sports", 18:"Short Movies", 19:"Travel & Events", 20:"Gaming", 21:"Videoblogging",
    22:"People & Blogs", 23:"Comedy", 24:"Entertainment", 25:"News & Politics",
    26:"Howto & Style", 27:"Education", 28:"Science & Technology", 29:"Nonprofits & Activism",
    30:"Movies", 31:"Anime/Animation", 32:"Action/Adventure", 33:"Classics", 34:"Comedy",
    35:"Documentary", 36:"Drama", 37:"Family", 38:"Foreign", 39:"Horror", 40:"Sci-Fi/Fantasy",
    41:"Thriller", 42:"Shorts", 43:"Shows", 44:"Trailers"}

# Convert category_id to category
CA_transformed["category_id"].replace(categories, inplace=True)

# Change "category_id" column name to "category"
CA_transformed = CA_transformed.rename(columns={"category_id":"category"})

# Clean the data by dropping duplicates and setting the index
CA_transformed.drop_duplicates("video_id", inplace=True)
CA_transformed.set_index("video_id", inplace=True)
#CA_transformed = CA_transformed.sort_values(by=["views", "likes"], ascending=False)

CA_transformed.head()
# Out:
#             trending_date                                              title  \
# video_id
# n1WpP7iowLc      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 0dBIkQ4Mz1M      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
# 2Vv-BfVoq4g      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#
#                   category              publish_time country     views  \
# video_id
# n1WpP7iowLc          Music  2017-11-10T17:00:03.000Z  Canada  17158579
# 0dBIkQ4Mz1M         Comedy  2017-11-13T17:00:00.000Z  Canada   1014651
# 5qpjK5DgCt4         Comedy  2017-11-12T19:05:24.000Z  Canada   3191434
# d380meD0W0M  Entertainment  2017-11-12T18:01:41.000Z  Canada   2095828
# 2Vv-BfVoq4g          Music  2017-11-09T11:04:14.000Z  Canada  33523622
#
#                likes  dislikes  comment_count
# ...

# %% [markdown]
# ### Transform Mexico DataFrame

# %%
# Create a filtered DataFrame from specific columns
MX_cols = ["video_id", "trending_date", "title", "category_id", "publish_time",
           "views", "likes", "dislikes", "comment_count"]
MX_transformed = MX_df[MX_cols].copy()

# Add a column to specify country
MX_transformed.insert(5, "country", "Mexico")

# Create a dict to convert category_id to category name
categories = {
    1:"Film & Animation", 2:"Autos & Vehicles", 10:"Music", 15:"Pets & Animals",
    17:"Sports", 18:"Short Movies", 19:"Travel & Events", 20:"Gaming", 21:"Videoblogging",
    22:"People & Blogs", 23:"Comedy", 24:"Entertainment", 25:"News & Politics",
    26:"Howto & Style", 27:"Education", 28:"Science & Technology", 29:"Nonprofits & Activism",
    30:"Movies", 31:"Anime/Animation", 32:"Action/Adventure", 33:"Classics", 34:"Comedy",
    35:"Documentary", 36:"Drama", 37:"Family", 38:"Foreign", 39:"Horror", 40:"Sci-Fi/Fantasy",
    41:"Thriller", 42:"Shorts", 43:"Shows", 44:"Trailers"}

# Convert category_id to category
MX_transformed["category_id"].replace(categories, inplace=True)

# Change "category_id" column name to "category"
MX_transformed = MX_transformed.rename(columns={"category_id":"category"})

# Clean the data by dropping duplicates and setting the index
MX_transformed.drop_duplicates("video_id", inplace=True)
MX_transformed.set_index("video_id", inplace=True)
#MX_transformed = MX_transformed.sort_values(by=["views", "likes"], ascending=False)

MX_transformed.head()
# Out:
#             trending_date                                              title  \
# video_id
# SbOwzAl9ZfQ      17.14.11                     CapÃ­tulo 12 | MasterChef 2017
# klOV6Xh-DnI      17.14.11  ALEXA EX-INTEGRANTE DEL GRUPO TIMBIRICHE RENUN...
# 6L2ZF7Qzsbk      17.14.11           LOUIS CKAGÃ - EL PULSO DE LA REPÃBLICA
# hcY52MFWMDM      17.14.11   Sismo de 6.7 sacude Costa Rica 12 Noviembre 2017
# _OXDcGPVAa4      17.14.11           DOG HACKS | MUSAS LESSLIE LOS POLINESIOS
#
#                     category              publish_time country   views  likes  \
# video_id
# SbOwzAl9ZfQ    Entertainment  2017-11-13T06:06:22.000Z  Mexico  310130   4182
# klOV6Xh-DnI   People & Blogs  2017-11-13T05:11:58.000Z  Mexico  104972    271
# 6L2ZF7Qzsbk  News & Politics  2017-11-13T17:00:02.000Z  Mexico  136064  10105
# hcY52MFWMDM  News & Politics  2017-11-13T03:47:10.000Z  Mexico   96153    378
# _OXDcGPVAa4    Howto & Style  2017-11-13T19:17:48.000Z  Mexico  499965  57781
#
# ...

# %% [markdown]
# ### Transform United States DataFrame

# %%
# Create a filtered DataFrame from specific columns
US_cols = ["video_id", "trending_date", "title", "category_id", "publish_time",
           "views", "likes", "dislikes", "comment_count"]
US_transformed = US_df[US_cols].copy()

# Add a column to specify country
US_transformed.insert(5, "country", "USA")

# Create a dict to convert category_id to category name
categories = {
    1:"Film & Animation", 2:"Autos & Vehicles", 10:"Music", 15:"Pets & Animals",
    17:"Sports", 18:"Short Movies", 19:"Travel & Events", 20:"Gaming", 21:"Videoblogging",
    22:"People & Blogs", 23:"Comedy", 24:"Entertainment", 25:"News & Politics",
    26:"Howto & Style", 27:"Education", 28:"Science & Technology", 29:"Nonprofits & Activism",
    30:"Movies", 31:"Anime/Animation", 32:"Action/Adventure", 33:"Classics", 34:"Comedy",
    35:"Documentary", 36:"Drama", 37:"Family", 38:"Foreign", 39:"Horror", 40:"Sci-Fi/Fantasy",
    41:"Thriller", 42:"Shorts", 43:"Shows", 44:"Trailers"}

# Convert category_id to category
US_transformed["category_id"].replace(categories, inplace=True)

# Change "category_id" column name to "category"
US_transformed = US_transformed.rename(columns={"category_id":"category"})

# Clean the data by dropping duplicates and setting the index
US_transformed.drop_duplicates("video_id", inplace=True)
US_transformed.set_index("video_id", inplace=True)
#US_transformed = US_transformed.sort_values(by=["views", "likes"], ascending=False)

US_transformed.head()
# Out:
#             trending_date                                              title  \
# video_id
# 2kyS6SvSYSE      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1ZAPwfrtAFY      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# puqaWrEC7tY      17.14.11                   Nickelback Lyrics: Real or Fake?
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
#
#                    category              publish_time country    views  \
# video_id
# 2kyS6SvSYSE  People & Blogs  2017-11-13T17:13:01.000Z     USA   748374
# 1ZAPwfrtAFY   Entertainment  2017-11-13T07:30:00.000Z     USA  2418783
# 5qpjK5DgCt4          Comedy  2017-11-12T19:05:24.000Z     USA  3191434
# puqaWrEC7tY   Entertainment  2017-11-13T11:00:04.000Z     USA   343168
# d380meD0W0M   Entertainment  2017-11-12T18:01:41.000Z     USA  2095731
#
#               likes  dislikes  comment_count
# ...

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:postgres@localhost:5432/NAYT_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()

# %% [markdown]
# ### Load DataFrames into database

# %%
CA_transformed.to_sql(name='premise', con=engine, if_exists='append', index=True)

# %%
MX_transformed.to_sql(name='premise', con=engine, if_exists='append', index=True)

# %%
US_transformed.to_sql(name='premise', con=engine, if_exists='append', index=True)
